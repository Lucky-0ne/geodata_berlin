# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## df_03_Einwohners_in_Berlin_seit_2013_nach_Bezirken.xlsx

# %%
df_03 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/03_Einwohners_in_Berlin_seit_2013_nach_Bezirken.xlsx', index_col=0)
df_03
# Out:
#                             2013-12-31  2014-12-31  2015-12-31  2016-12-31  \
# population
# Berlin                         3517424     3562166     3610156     3670622
# Mitte                           348102      356506      363236      371407
# Friedrichshain-Kreuzberg        273517      275691      278393      281323
# Pankow                          377532      384367      389976      397406
# Charlottenburg-Wilmersdorf      322870      326354      330468      336249
# Spandau                         226868      230419      234630      239942
# Steglitz-Zehlendorf             298200      299268      299765      304086
# Tempelhof-Schöneberg            331822      335767      341161      346108
# Neukölln                        322153      325716      328062      327522
# Treptow-Köpenick                245951      249440      253333      259524
# Marzahn-Hellersdorf             254226      256173      259373      262015
# ...

# %%
df_03.reset_index(inplace=True)
df_03.rename(columns={'population': 'district'}, inplace=True)
df_03
# Out:
#                       district  2013-12-31  2014-12-31  2015-12-31  \
# 0                       Berlin     3517424     3562166     3610156
# 1                        Mitte      348102      356506      363236
# 2     Friedrichshain-Kreuzberg      273517      275691      278393
# 3                       Pankow      377532      384367      389976
# 4   Charlottenburg-Wilmersdorf      322870      326354      330468
# 5                      Spandau      226868      230419      234630
# 6          Steglitz-Zehlendorf      298200      299268      299765
# 7         Tempelhof-Schöneberg      331822      335767      341161
# 8                     Neukölln      322153      325716      328062
# 9             Treptow-Köpenick      245951      249440      253333
# 10         Marzahn-Hellersdorf      254226      256173      259373
# 11                 Lichtenberg      264858      268465      275142
# 12               Reinickendorf      251325      254000      256617
#
# ...

# %%
df_03[df_03['district']!='Berlin']['2023-12-31'].sum()
# Out:
# 3878100

# %%
df_03 = df_03[df_03['district'] != 'Berlin']
df_03
# Out:
#                       district  2013-12-31  2014-12-31  2015-12-31  \
# 1                        Mitte      348102      356506      363236
# 2     Friedrichshain-Kreuzberg      273517      275691      278393
# 3                       Pankow      377532      384367      389976
# 4   Charlottenburg-Wilmersdorf      322870      326354      330468
# 5                      Spandau      226868      230419      234630
# 6          Steglitz-Zehlendorf      298200      299268      299765
# 7         Tempelhof-Schöneberg      331822      335767      341161
# 8                     Neukölln      322153      325716      328062
# 9             Treptow-Köpenick      245951      249440      253333
# 10         Marzahn-Hellersdorf      254226      256173      259373
# 11                 Lichtenberg      264858      268465      275142
# 12               Reinickendorf      251325      254000      256617
#
#     2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31  \
# ...

# %%
# df_03.to_csv(r'Statistik_Berlin_Brandenburg\manual_split\preprocessed_data\population_Berlin_districts_2013_2023.csv', index=False)
df_03
# Out:
#                       district  2013-12-31  2014-12-31  2015-12-31  \
# 1                        Mitte      348102      356506      363236
# 2     Friedrichshain-Kreuzberg      273517      275691      278393
# 3                       Pankow      377532      384367      389976
# 4   Charlottenburg-Wilmersdorf      322870      326354      330468
# 5                      Spandau      226868      230419      234630
# 6          Steglitz-Zehlendorf      298200      299268      299765
# 7         Tempelhof-Schöneberg      331822      335767      341161
# 8                     Neukölln      322153      325716      328062
# 9             Treptow-Köpenick      245951      249440      253333
# 10         Marzahn-Hellersdorf      254226      256173      259373
# 11                 Lichtenberg      264858      268465      275142
# 12               Reinickendorf      251325      254000      256617
#
#     2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31  \
# ...

# %%
df = pd.read_csv('Statistik_Berlin_Brandenburg/manual_split/preprocessed_data/population_Berlin_districts_2013_2023.csv')
df
# Out:
#                       district  2013-12-31  2014-12-31  2015-12-31  \
# 0                        Mitte      348102      356506      363236
# 1     Friedrichshain-Kreuzberg      273517      275691      278393
# 2                       Pankow      377532      384367      389976
# 3   Charlottenburg-Wilmersdorf      322870      326354      330468
# 4                      Spandau      226868      230419      234630
# 5          Steglitz-Zehlendorf      298200      299268      299765
# 6         Tempelhof-Schöneberg      331822      335767      341161
# 7                     Neukölln      322153      325716      328062
# 8             Treptow-Köpenick      245951      249440      253333
# 9          Marzahn-Hellersdorf      254226      256173      259373
# 10                 Lichtenberg      264858      268465      275142
# 11               Reinickendorf      251325      254000      256617
#
#     2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31  \
# ...

# %% [markdown]
# ## df_11_Einwohners_in_Berlin_am_31_Dezember_2023_nach_Ortsteilen_Alter_gender.xlsx

# %%
df_11 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/11_Einwohners_in_Berlin_am_31_Dezember_2023_nach_Ortsteilen_Alter_gender.xlsx', index_col=0)
df_11
# Out:
#                       total   < 6  6 - 14  15 - 17  18 - 26  27 - 44  45 - 54  \
# local_district_name
# Mitte                107875  5873    7533     2253    10880    41003    14672
# Moabit                84113  4471    5726     1825    10639    31859     9345
# Hansaviertel           6075   194     286       75      995     1928      607
# Tiergarten            16313   789    1066      295     2065     5826     1874
# Wedding               86926  4567    5876     1984    11714    31915     9590
# ...                     ...   ...     ...      ...      ...      ...      ...
# Waidmannslust         11263   791    1234      405     1155     2560     1324
# Lübars                 5068   206     512      174      351      876      657
# Wittenau              25106  1224    1721      496     2343     5786     2744
# Märkisches Viertel    41167  2802    4914     1617     4710     9516     4746
# Borsigwalde            6899   377     414      124      676     1988      798
#
# ...

# %%
df_11.reset_index(inplace=True)
df_11
# Out:
#    local_district_name   total   < 6  6 - 14  15 - 17  18 - 26  27 - 44  \
# 0                Mitte  107875  5873    7533     2253    10880    41003
# 1               Moabit   84113  4471    5726     1825    10639    31859
# 2         Hansaviertel    6075   194     286       75      995     1928
# 3           Tiergarten   16313   789    1066      295     2065     5826
# 4              Wedding   86926  4567    5876     1984    11714    31915
# ..                 ...     ...   ...     ...      ...      ...      ...
# 92       Waidmannslust   11263   791    1234      405     1155     2560
# 93              Lübars    5068   206     512      174      351      876
# 94            Wittenau   25106  1224    1721      496     2343     5786
# 95  Märkisches Viertel   41167  2802    4914     1617     4710     9516
# 96         Borsigwalde    6899   377     414      124      676     1988
#
#     45 - 54  55 - 64  65 <=  female_share
# 0     14672    11923  13738         53117
# ...

# %%
# df_11.to_csv(r'Statistik_Berlin_Brandenburg\manual_split\preprocessed_data\population_age_gender_Berlin_local_districts_20231231.csv', index=False)
df_11
# Out:
#    local_district_name   total   < 6  6 - 14  15 - 17  18 - 26  27 - 44  \
# 0                Mitte  107875  5873    7533     2253    10880    41003
# 1               Moabit   84113  4471    5726     1825    10639    31859
# 2         Hansaviertel    6075   194     286       75      995     1928
# 3           Tiergarten   16313   789    1066      295     2065     5826
# 4              Wedding   86926  4567    5876     1984    11714    31915
# ..                 ...     ...   ...     ...      ...      ...      ...
# 92       Waidmannslust   11263   791    1234      405     1155     2560
# 93              Lübars    5068   206     512      174      351      876
# 94            Wittenau   25106  1224    1721      496     2343     5786
# 95  Märkisches Viertel   41167  2802    4914     1617     4710     9516
# 96         Borsigwalde    6899   377     414      124      676     1988
#
#     45 - 54  55 - 64  65 <=  female_share
# 0     14672    11923  13738         53117
# ...

# %%
df = pd.read_csv('Statistik_Berlin_Brandenburg/manual_split/preprocessed_data/population_age_gender_Berlin_local_districts_20231231.csv')
df
# Out:
#    local_district_name   total   < 6  6 - 14  15 - 17  18 - 26  27 - 44  \
# 0                Mitte  107875  5873    7533     2253    10880    41003
# 1               Moabit   84113  4471    5726     1825    10639    31859
# 2         Hansaviertel    6075   194     286       75      995     1928
# 3           Tiergarten   16313   789    1066      295     2065     5826
# 4              Wedding   86926  4567    5876     1984    11714    31915
# ..                 ...     ...   ...     ...      ...      ...      ...
# 92       Waidmannslust   11263   791    1234      405     1155     2560
# 93              Lübars    5068   206     512      174      351      876
# 94            Wittenau   25106  1224    1721      496     2343     5786
# 95  Märkisches Viertel   41167  2802    4914     1617     4710     9516
# 96         Borsigwalde    6899   377     414      124      676     1988
#
#     45 - 54  55 - 64  65 <=  female_share
# 0     14672    11923  13738         53117
# ...

# %% [markdown]
# ## df_14_Einwohners_in_Berlin_am_31_Dezember_2023_nach_PLZ_Alter_gender.xlsx

# %%
df_12 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/14_Einwohners_in_Berlin_am_31_Dezember_2023_nach_PLZ_Alter_gender.xlsx', index_col=0)
df_12
# Out:
#                   disctrict  total   < 6  6 - 14  15 - 17  18 - 26  27 - 44  \
# PLZ
# 10115                 Mitte  28315  1706    2294      733     2727    11587
# 10117                 Mitte  17438   922    1079      306     1648     6414
# 10119                 Mitte  14887   756    1087      382     1329     5756
# 10119                Pankow   4970   243     418      116      515     1801
# 10178  Friedrichsh.-Kreuzb.     72     0       9        0        3       33
# ...                     ...    ...   ...     ...      ...      ...      ...
# 14197    Charlbg.-Wilmersd.  17229   724    1129      383     1403     3737
# 14197     Steglitz-Zehlend.    386    15      30        9       32       79
# 14197     Tempelh.-Schöneb.   1369    51     100       27      126      441
# 14199    Charlbg.-Wilmersd.  17572   892    1431      433     1554     4191
# 14199     Steglitz-Zehlend.     28     0       0        0        3        6
#
#        45 - 54  55 - 64  65 <=  female_share
# PLZ
# ...

# %%
df_12.reset_index(inplace=True)
df_12
# Out:
#        PLZ             disctrict  total   < 6  6 - 14  15 - 17  18 - 26  \
# 0    10115                 Mitte  28315  1706    2294      733     2727
# 1    10117                 Mitte  17438   922    1079      306     1648
# 2    10119                 Mitte  14887   756    1087      382     1329
# 3    10119                Pankow   4970   243     418      116      515
# 4    10178  Friedrichsh.-Kreuzb.     72     0       9        0        3
# ..     ...                   ...    ...   ...     ...      ...      ...
# 232  14197    Charlbg.-Wilmersd.  17229   724    1129      383     1403
# 233  14197     Steglitz-Zehlend.    386    15      30        9       32
# 234  14197     Tempelh.-Schöneb.   1369    51     100       27      126
# 235  14199    Charlbg.-Wilmersd.  17572   892    1431      433     1554
# 236  14199     Steglitz-Zehlend.     28     0       0        0        3
#
#      27 - 44  45 - 54  55 - 64  65 <=  female_share
# ...

# %%
# df_12.to_csv(r'Statistik_Berlin_Brandenburg\manual_split\preprocessed_data\population_age_gender_Berlin_PLZ_20231231.csv', index=False)
df_12
# Out:
#        PLZ             disctrict  total   < 6  6 - 14  15 - 17  18 - 26  \
# 0    10115                 Mitte  28315  1706    2294      733     2727
# 1    10117                 Mitte  17438   922    1079      306     1648
# 2    10119                 Mitte  14887   756    1087      382     1329
# 3    10119                Pankow   4970   243     418      116      515
# 4    10178  Friedrichsh.-Kreuzb.     72     0       9        0        3
# ..     ...                   ...    ...   ...     ...      ...      ...
# 232  14197    Charlbg.-Wilmersd.  17229   724    1129      383     1403
# 233  14197     Steglitz-Zehlend.    386    15      30        9       32
# 234  14197     Tempelh.-Schöneb.   1369    51     100       27      126
# 235  14199    Charlbg.-Wilmersd.  17572   892    1431      433     1554
# 236  14199     Steglitz-Zehlend.     28     0       0        0        3
#
#      27 - 44  45 - 54  55 - 64  65 <=  female_share
# ...

# %%
df = pd.read_csv('Statistik_Berlin_Brandenburg/manual_split/preprocessed_data/population_age_gender_Berlin_PLZ_20231231.csv')
df
# Out:
#        PLZ             disctrict  total   < 6  6 - 14  15 - 17  18 - 26  \
# 0    10115                 Mitte  28315  1706    2294      733     2727
# 1    10117                 Mitte  17438   922    1079      306     1648
# 2    10119                 Mitte  14887   756    1087      382     1329
# 3    10119                Pankow   4970   243     418      116      515
# 4    10178  Friedrichsh.-Kreuzb.     72     0       9        0        3
# ..     ...                   ...    ...   ...     ...      ...      ...
# 232  14197    Charlbg.-Wilmersd.  17229   724    1129      383     1403
# 233  14197     Steglitz-Zehlend.    386    15      30        9       32
# 234  14197     Tempelh.-Schöneb.   1369    51     100       27      126
# 235  14199    Charlbg.-Wilmersd.  17572   892    1431      433     1554
# 236  14199     Steglitz-Zehlend.     28     0       0        0        3
#
#      27 - 44  45 - 54  55 - 64  65 <=  female_share
# ...

# %% [markdown]
# # REST

# %%
dis = gpd.read_file('ODIS_base_dataset/bezirksgrenzen.shp')
dis.head(3)
# Out:
#                        gml_id                  Gemeinde_n Gemeinde_s  \
# 0  s_wfs_alkis_bezirk.F176__1               Reinickendorf        012
# 1  s_wfs_alkis_bezirk.F176__2  Charlottenburg-Wilmersdorf        004
# 2  s_wfs_alkis_bezirk.F176__3            Treptow-Köpenick        009
#
#   Land_name Land_schlu Schluessel  \
# 0    Berlin         11   11000012
# 1    Berlin         11   11000004
# 2    Berlin         11   11000009
#
#                                             geometry
# 0  POLYGON ((13.32074 52.62660, 13.32104 52.62658...
# 1  POLYGON ((13.32111 52.52446, 13.32137 52.52452...
# 2  POLYGON ((13.57925 52.39083, 13.57894 52.39078...

# %%
df = dis[['Gemeinde_n', 'Gemeinde_s', 'geometry']]
df.head(3)
# Out:
#                    Gemeinde_n Gemeinde_s  \
# 0               Reinickendorf        012
# 1  Charlottenburg-Wilmersdorf        004
# 2            Treptow-Köpenick        009
#
#                                             geometry
# 0  POLYGON ((13.32074 52.62660, 13.32104 52.62658...
# 1  POLYGON ((13.32111 52.52446, 13.32137 52.52452...
# 2  POLYGON ((13.57925 52.39083, 13.57894 52.39078...

# %%
wiki_dis = pd.DataFrame({
    'Bezirk':['Mitte',
              '...'],
    'Ortsteil_ID': [['0101','0102','0103','0104','0105','0106'],
                    '...'],
    'Ortsteil_NAME': [['Mitte','Moabit','Hansaviertel','Tiergarten','Wedding','Gesundbrunnen'],
                      '...'],
    'size_km2':[39.47,
                    0],
    'population':[397134,
                    0],
    'pop_per_km2':[10062,
                    0],
    'state':['31.12.2023',
             '31.12.2023']
    })
# wiki_dis = pd.DataFrame({
#     'Bezirk':['Mitte'],
#     'Ortsteil [(ID,NAME)]': [[('0101','Mitte'), ('0102','Moabit'), ('0103','Hansaviertel'), ('0104','Tiergarten'), ('0105','Wedding'), ('0106','Gesundbrunnen')]],
#     'size_km2':[39.47],
#     'population':[397134],
#     'pop_per_km2':[10062],
#     'state':['31.12.2023']
#     })
wiki_dis
# Out:
#   Bezirk                           Ortsteil_ID  \
# 0  Mitte  [0101, 0102, 0103, 0104, 0105, 0106]
# 1    ...                                   ...
#
#                                        Ortsteil_NAME  size_km2  population  \
# 0  [Mitte, Moabit, Hansaviertel, Tiergarten, Wedd...     39.47      397134
# 1                                                ...      0.00           0
#
#    pop_per_km2       state
# 0        10062  31.12.2023
# 1            0  31.12.2023

# %%
# 'Ortsteil [(ID,NAME)]': [{
#         'ID':['0101', '0102', '0103', '0104', '0105', '0106'],
#         'NAME':['Mitte', 'Moabit', 'Hansaviertel', 'Tiergarten', 'Wedding', 'Gesundbrunnen']
#         }],

# %% [markdown]
# ## Statistik Berlin Brandenburg (Eigenkreation)

# %%
df_01 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/01_Deutsche_und_auslaendische_Einwohners_in_Berlin_seit_2000_nach_Geschlecht.xlsx')
df_01.head(3)
# Out:
#   reporting_date    total  m_total  f_total  ger_total  ger_m_total  \
# 0     2000-12-31  3331232  1616893  1714339    2896115      1383190
# 1     2001-12-31  3337232  1620941  1716291    2896886      1386122
# 2     2002-12-31  3336248  1621209  1715039    2893694      1387171
#
#    ger_f_total  frgn_total  frgn_m_total  frgn_f_total
# 0      1512925      435117        233703        201414
# 1      1510764      440346        234819        205527
# 2      1506523      442554        234038        208516

# %%
df_03 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/03_Einwohners_in_Berlin_seit_2013_nach_Bezirken.xlsx')
df_03
# Out:
#    reporting_date   Berlin   Mitte  Friedrichshain-Kreuzberg  Pankow  \
# 0      2013-12-31  3517424  348102                    273517  377532
# 1      2014-12-31  3562166  356506                    275691  384367
# 2      2015-12-31  3610156  363236                    278393  389976
# 3      2016-12-31  3670622  371407                    281323  397406
# 4      2017-12-31  3711930  377965                    283974  402289
# 5      2018-12-31  3748148  383457                    289120  407039
# 6      2019-12-31  3769495  385748                    290386  409335
# 7      2020-12-31  3769962  383360                    289787  410716
# 8      2021-12-31  3775480  385692                    289014  413168
# 9      2022-12-31  3850809  395599                    293231  420768
# 10     2023-12-31  3878100  397134                    293454  424307
#
#     Charlottenburg-Wilmersdorf  Spandau  Steglitz-Zehlendorf  \
# 0                       322870   226868               298200
# ...

# %%
df_04 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/04_Durchschnittsalter_der_Einwohners_in_Berlin_seit_2013_nach_Bezirken_in_Jahren.xlsx')
df_04
# Out:
#    reporting_date  Berlin  Mitte  Friedrichshain-Kreuzberg  Pankow  \
# 0      2013-12-31    42.9   39.1                      37.5    40.8
# 1      2014-12-31    42.9   39.1                      37.7    40.8
# 2      2015-12-31    42.8   39.0                      37.7    40.7
# 3      2016-12-31    42.7   38.9                      37.8    40.7
# 4      2017-12-31    42.7   38.9                      37.9    40.7
# 5      2018-12-31    42.7   38.9                      38.1    40.8
# 6      2019-12-31    42.8   39.0                      38.2    40.9
# 7      2020-12-31    42.8   39.0                      38.2    40.9
# 8      2021-12-31    42.9   39.2                      38.7    41.2
# 9      2022-12-31    42.7   39.1                      38.8    41.2
# 10     2023-12-31    42.7   39.3                      39.1    41.4
#
#     Charlottenburg-Wilmersdorf  Spandau  Steglitz-Zehlendorf  \
# 0                         45.8     44.4                 46.2
# ...

# %%
df_05 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/05_Einwohners_in_Berlin_am_31_Dezember_2023_nach_Bezirk_Alter_FamStand.xlsx')
df_05
# Out:
#         age    total  single_or_unknown  married  widowed  divorced  \
# 0      < 18   633482             633478        4        0         0
# 1   18 - 25   277845             269010     8679        3       153
# 2   25 - 30   288604             244370    42335       42      1750
# 3   30 - 35   338710             230711   100288      201      6880
# 4   35 - 40   334820             186867   131887      421     14313
# 5   40 - 45   288646             136229   128086      887     21612
# 6   45 - 50   237178              93771   113304     1750     26518
# 7   50 - 55   232946              76495   116540     3212     35012
# 8   55 - 60   268606              73276   137061     6940     49231
# 9   60 - 65   246506              50775   131968    11787     50417
# 10    65 <=   730757              68688   370204   170632    118797
# 11    total  3878100            2063670  1280356   195875    324683
#
#     civil_partnership
# 0                   0
# 1                   0
# ...

# %%
df_06_1 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/06_1_Einwohners_in_Berlin_am_31_Dezember_2023_nach_Bezirken_Alter_genderTotal.xlsx')
df_06_2 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/06_2_Einwohners_in_Berlin_am_31_Dezember_2023_nach_Bezirken_Alter_genderMale.xlsx')
df_06_3 = pd.read_excel('Statistik_Berlin_Brandenburg/manual_split/06_3_Einwohners_in_Berlin_am_31_Dezember_2023_nach_Bezirken_Alter_genderFemale.xlsx')
display(df_06_1, df_06_2, df_06_3)
# Out:
#         age gender   Berlin   Mitte  Friedrichshain-Kreuzberg  Pankow  \
# 0     total   both  3878100  397134                    293454  424307
# 1       < 6   both   215179   21562                     15842   23722
# 2    6 - 14   both   319255   29450                     21556   38032
# 3   15 - 17   both    99048    9378                      6572   11670
# 4   18 - 19   both    67562    6945                      4594    7474
# 5   20 - 24   both   210283   26703                     15947   20398
# 6   25 - 29   both   288604   42760                     27606   28907
# 7   30 - 34   both   338710   47954                     36088   37448
# 8   35 - 39   both   334820   39598                     33953   40325
# 9   40 - 44   both   288646   30269                     28111   36275
# 10  45 - 59   both   738730   71320                     57291   93487
# 11  60 - 64   both   246506   20355                     14556   23992
# ...

# %%
df_06_1[df_06_1['age']=='total'].drop(columns=['age', 'gender']).T
# Out:
#                                   0
# Berlin                      3878100
# Mitte                        397134
# Friedrichshain-Kreuzberg     293454
# Pankow                       424307
# Charlottenburg-Wilmersdorf   343081
# Spandau                      257091
# Steglitz-Zehlendorf          310446
# Tempelhof-Schöneberg         355868
# Neukölln                     330017
# Treptow-Köpenick             294081
# Marzahn-Hellersdorf          291948
# Lichtenberg                  311881
# Reinickendorf                268792
